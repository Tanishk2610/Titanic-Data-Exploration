# %% [markdown]
# # Assignment 1: Access an open source dataset “Titanic”. Apply pre-processing techniques on the raw dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Titanic_dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Handling Missing Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df = df.drop(columns=['Ticket', 'PassengerId', 'Cabin'], axis = 1)

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
df.shape
# Out:
# (891, 9)

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df[df['Embarked'].isnull()]
# Out:
#      Survived  Pclass                                       Name     Sex  \
# 61          1       1                        Icard, Miss. Amelie  female
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#       Age  SibSp  Parch  Fare Embarked
# 61   38.0      0      0  80.0      NaN
# 829  62.0      0      0  80.0      NaN

# %%
#Drop this above two rows.
df = df.drop([61, 829])

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# dtype: int64

# %%
# Calculate the median of the 'Age' column
median_age = df['Age'].median()

# Fill missing values in the 'Age' column with the median
df['Age'].fillna(median_age, inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(12,6), dpi = 300)
df.corr()
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8), dpi=300)
sns.catplot(data = df, x="Sex", y="Survived", hue="Pclass", kind="bar")

# %%
sns.pairplot(data=df, hue="Survived")

# %%
plt.figure(dpi=200)
sns.countplot(x='SibSp', data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
plt.figure(dpi=200)
sns.boxplot(x='Pclass', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
plt.figure(dpi=300)
sns.lineplot(x='Age', y='Fare', data=df)
plt.title('Time Series Line Plot')
plt.show()

# %%
plt.figure(dpi=300)
sns.regplot(x='SibSp', y='Parch', data=df)
plt.title('Scatter Plot with Trendline')
plt.show()

# %% [markdown]
# # Encoding Categorial Data

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    312
# Name: Sex, dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.corr()['Survived'].sort_values()
# Out:
# Pclass     -0.335549
# Age        -0.069822
# SibSp      -0.034040
# Parch       0.083151
# Fare        0.255290
# Survived    1.000000
# Name: Survived, dtype: float64

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'column_name' is the name of the column you want to create dummies for
column_name = 'your_Sex'

# Get dummies for the specified column
dummies = pd.get_dummies(df["Sex"])

# Optionally, you can specify prefix for the dummy columns
# dummies = pd.get_dummies(df[column_name], prefix=column_name)

# Concatenate the dummies with the original DataFrame
df_with_dummies = pd.concat([df, dummies], axis=1)

# Optionally, you might want to drop the original column if you don't need it anymore
# df_with_dummies.drop(column_name, axis=1, inplace=True)

# %%
Outliers=[]

def detect_outliers(final_df):
    
        threshold = 3
        mean = np.mean(final_df)
        std = np.std(final_df)
        
        for i in final_df:
            Z_Score = (i - mean)/std
            if np.abs(Z_Scores) > threshold:
                outliers.append(i)
        return outliers
